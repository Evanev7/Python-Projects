# %%
from matplotlib import pyplot as plt
import json
import pymysql.cursors
import pymysql

# %%
# Connect to the database
connection = pymysql.connect(host='localhost',
                             user='root',
                             password='root',
                             db='kol',
                             charset='utf8mb4',
                             cursorclass=pymysql.cursors.DictCursor)

try:
    with connection.cursor() as cursor:
        cursor.execute("SELECT * FROM user_audience_analyses")
        result = cursor.fetchone()
        print(result)
finally:
    connection.close()
# Out:
# {'id': 1, 'user_id': 1, 'platform': 'instagram', 'influencer_id': 'juraaa19', 'influencer_username': 'juraaa19', 'business_url': 'https://www.instagram.com/juraaa19', 'influencer_picture': 'https://imgp.sptds.icu/v2?mb0KwpL92uYofJiSjDn1%2F6peL1lBwv3s%2BUvShHERlDbuwW0Ef%2BRcyAokGxb3wwGtYz2%2FqzZnQGBl6F9JB8uAD%2Fr715FWnv5O%2FCks11V6n%2FPaHUf%2BKSlqi%2BhuS%2F%2FR8EIUgNlJUwVYqIiahjW32e%2BqWA%3D%3D', 'influencer_fullname': 'JURA', 'influencer_description': '京都二寧坂で似顔絵描いてます🦋\nお店は予約不可となってますので当日ご来店ください✨\n【住所】〒605-0826 \n📍京都府京都市東山区桝屋町３５１−６\n【営業時間】\n10時半〜18時(最終受付)', 'is_verified': 0, 'is_business': 0, 'account_type': 'CREATOR', 'gender': 'FEMALE', 'language': 'ja', 'followers': 108336, 'posts_count': 97, 'engagements': None, 'engagement_rate': 0.04, 'avg_likes': 4482, 'avg_comments': 21, 'avg_views': 0, 'avg_reels_plays': 435465, 'stat_history': '[{"month": "2023-08", "total_likes": null, "total_views": null, "average_likes": 4128, "average_views": null, "follower_count": 74378, "following_count": 284, "average_comments": null, "subscriber_count": null}, {"month": "2023-09", "total_likes": null, "total_views": null, "average_likes": 3904, "average_views": null, "follower_count": 80056, "following_count": 292, "average_comments": null, "subscriber_count": null}, {"month": "2023-10", "total_likes": null, "total_views": null, "average_likes": 4996, "average_views": null, "follower_count": 85092, "following_count": 294, "average_comments": null, "subscriber_count": null}, {"month": "2023-11", "total_likes": null, "total_views": null, "average_likes": 2892, "average_views": null, "follower_count": 91754, "following_count": 296, "average_comments": null, "subscriber_count": null}, {"month": "2023-12", "total_likes": null, "total_views": null, "average_likes": 3180, "average_views": null, "follower_count": 99404, "following_count": 299, "average_comments": null, "subscriber_count": null}, {"month": "2024-01", "total_likes": null, "total_views": null, "average_likes": 4482, "average_views": null, "follower_count": 108336, "following_count": 303, "average_comments": null, "subscriber_count": null}, {"month": "2024-02", "total_likes": null, "total_views": null, "average_likes": 4482, "average_views": null, "follower_count": 108336, "following_count": 303, "average_comments": null, "subscriber_count": null}]', 'paid_post_performance': None, 'top_hashtags': '[{"name": "似顔絵", "value": 42.8571}, {"name": "京都", "value": 33.928599999999996}, {"name": "二寧坂", "value": 30.3571}, {"name": "似顔絵師", "value": 26.7857}, {"name": "清水寺", "value": 24.1071}, {"name": "illustrator", "value": 21.4286}, {"name": "procreate", "value": 20.5357}, {"name": "二年坂", "value": 18.75}, {"name": "illustration", "value": 16.964299999999998}, {"name": "カリカチュアジャパン", "value": 16.964299999999998}, {"name": "drawing", "value": 16.0714}, {"name": "draw", "value": 16.0714}, {"name": "似顔絵オーダー", "value": 15.1786}, {"name": "instagram", "value": 14.285700000000002}, {"name": "insta", "value": 14.285700000000002}, {"name": "instagood", "value": 14.285700000000002}, {"name": "likeforfollow", "value": 13.3929}, {"name": "like4likes", "value": 13.3929}, {"name": "kyoto", "value": 13.3929}, {"name": "myart", "value": 12.5}, {"name": "art", "value": 12.5}, {"name": "likeforlikes", "value": 12.5}, {"name": "f4f", "value": 12.5}, {"name": "ipadpro", "value": 12.5}, {"name": "sketch", "value": 12.5}, {"name": "following", "value": 11.6071}, {"name": "follow4follow", "value": 11.6071}, {"name": "followforfollowback", "value": 11.6071}, {"name": "likeforlike", "value": 11.6071}, {"name": "follower", "value": 11.6071}]', 'top_mentions': '[{"name": "988qqdqz", "value": 37.037}, {"name": "jura_deai", "value": 35.1852}, {"name": "keiju__official", "value": 9.2593}, {"name": "cj_kyoto", "value": 7.4074}, {"name": "11___shun_528", "value": 3.7037}, {"name": "_genking_", "value": 3.7037}, {"name": "maomao_kobe", "value": 3.7037}]', 'brand_affinity': '[]', 'interests': '[{"name": "Restaurants, Food & Grocery" ...

# %%
def histogram(edges, values):
    output = []
    if len(values) == len(edges):
        for i in range(len(values)):
            output.append([edges[i]]*values[i])
    return np.histogram()
